# %%
import numpy as np
import pandas as pd

# %%
# import standard PyTorch modules
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter # TensorBoard support

# import torchvision module to handle image manipulation
import torchvision
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt

import tqdm
import time

torch.set_printoptions(linewidth=120)
torch.set_grad_enabled(True)
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
from datasets import load_dataset

dataset = load_dataset("nell", "nell_belief")
# Out:
# Reusing dataset nell (/Users/lemon/.cache/huggingface/datasets/nell/nell_belief/1115.0.0/0b3db04630c4a5967fc48a0539dd09ed64510d63837975cd187cf73d99f6e3ff)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['entity', 'relation', 'value', 'iteration_of_promotion', 'score', 'source', 'entity_literal_strings', 'value_literal_strings', 'best_entity_literal_string', 'best_value_literal_string', 'categories_for_entity', 'categories_for_value', 'candidate_source'],
#         num_rows: 2766079
#     })
# })

# %%
entity = dataset['train']['entity'][1 : 10001]

# %%
# Out:
# 6335

# %%
relation = dataset['train']['relation'][1 : 10001]

# %%
for j in range(300):
    print(entity[j])
    print(relation[j])
# Out:
# concept:biotechcompany:aspect_medical_systems
# generalizations
# concept:company:limited_brands
# concept:companyceo
# concept:company:limited_brands
# generalizations
# concept:company:limited_brands
# generalizations
# concept:biotechcompany:calavo_growers
# generalizations
# concept:biotechcompany:playboy_enterprises_inc
# generalizations
# concept:biotechcompany:b_c_s_b_bancorp_inc
# generalizations
# concept:biotechcompany:boeing_integrated_defense_systems
# generalizations
# concept:company:mahindra___mahindra_ltd_
# generalizations
# concept:biotechcompany:marsam_pharmaceuticals
# generalizations
# concept:biotechcompany:sifco_industries_inc
# generalizations
# concept:biotechcompany:medecins_sans_frontieres
# concept:organizationalsoknownas
# concept:biotechcompany:acceleron
# concept:haswikipediaurl
# concept:biotechcompany:acceleron
# generalizations
# concept:biotechcompany:midwestone_financial_group_inc
# generalizations
# concept:company:verifone
# generalizations
# concept:biotechcompany:anntaylor_stores_corp
# generalizations
# concept:biotechcompany:magma_design_automation_inc
# generalizations
# concept:biotechcompany:u_s__concrete
# generalizations
# concept:biotechcompany:foster_s_group_limited
# concept:haswikipediaurl
# concept:biotechcompany:abgenix
# generalizations
# concept:biotechcompany:nupathe
# generalizations
# concept:biotechcompany:united_retail_group_inc
# concept:haswikipediaurl
# concept:biotechcompany:united_retail_group_inc
# generalizations
# concept:biotechcompany:universal_security_instruments_inc
# generalizations
# concept:biotechcompany:eisai_inc
# generalizations
# concept:biotechcompany:eresearch_technology
# generalizations
# concept:biotechcompany:n3_6_teva_and_ratiopharm
# generalizations
# concept:biotechcompany:american_church_mortgage_co
# generalizations
# concept:biotechcompany:transduction_laboratories
# generalizations
# concept:biotechcompany:china_finance_online_co__ltd
# generalizations
# concept:biotechcompany:sherman_pharmaceuticals
# generalizations
# concept:biotechcompany:coldwater_creek_inc
# generalizations
# concept:biotechcompany:coldwater_creek_inc
# generalizations
# concept:biotechcompany:investors_title_co
# generalizations
# concept:biotechcompany:orckit_communications_ltd
# generalizations
# concept:biotechcompany:intuit
# concept:acquired
# concept:biotechcompany:intuit
# concept:agentcollaborateswithagent
# concept:biotechcompany:intuit
# concept:agentcollaborateswithagent
# concept:biotechcompany:intuit
# concept:agentcollaborateswithagent
# concept:biotechcompany:intuit
# concept:agentcollaborateswithagent
# concept:biotechcompany:intuit
# concept:agentcontrols
# concept:biotechcompany:intuit
# concept:agentcontrols
# concept:biotechcompany:intuit
# concept:companyceo
# concept:biotechcompany:intuit
# concept:controlledbyagent
# concept:biotechcompany:intuit
# concept:mutualproxyfor
# concept:biotechcompany:intuit
# concept:mutualproxyfor
# concept:biotechcompany:intuit
# concept:organizationhasagent
# concept:biotechcompany:intuit
# concept:organizationhasagent
# concept:biotechcompany:intuit
# concept:organizationhasagent
# concept:biotechcompany:intuit
# concept:organizationhasperson
# concept:biotechcompany:intuit
# concept:organizationhasperson
# concept:biotechcompany:intuit
# concept:organizationhasperson
# concept:biotechcompany:intuit
# concept:organizationhastopmember
# concept:biotechcompany:intuit
# concept:organizationhastopmember
# concept:biotechcompany:intuit
# concept:organizationhiredperson
# concept:biotechcompany:intuit
# concept:organizationleadbyperson
# concept:biotechcompany:intuit
# concept:organizationleadbyperson
# concept:biotechcompany:intuit
# concept:organizationleadbyperson
# concept:biotechcompany:intuit
# concept:organizationterminatedperson
# concept:biotechcompany:intuit
# concept:organizationterminatedperson
# concept:biotechcompany:intuit
# concept:proxyof
# concept:biotechcompany:intuit
# concept:subpartof
# concept:biotechcompany:intuit
# concept:synonymfor
# concept:biotechcompany:intuit
# concept:worker
# concept:biotechcompany:intuit
# concept:worker
# concept:biotechcompany:intuit
# concept:worker
# concept:biotechcompany:intuit
# generalizations
# concept:biotechcompany:intuit
# generalizations
# concept:biotechcompany:aphton_corp
# generalizations
# concept:biotechcompany:powershares_dynamic_small_cap_value_portfolio
# generalizations
# concept:biotechcompany:lightbridge_inc_
# concept:companyalsoknownas
# concept:biotechcompany:premier_community_bankshares_inc
# generalizations
# concept:biotechcompany:manhattan_pharmaceuticals
# generalizations
# concept:biotechcompany:mandalay_resort_group
# concept:haswikipediaurl
# concept:biotechcompany:mandalay_resort_group
# generalizations
# concept:biotechcompany:immulogic_pharmaceutical_corp
# generalizations
# concept:biotechcompany:caredecision_corp
# generalizations
# concept:company:american_family_insurance
# concept:companyeconomicsector
# concept:company:american_family_insurance
# generalizations
# concept:biotechcompany:virginia_commerce_bancorp_inc
# generalizations
# concept:biotechcompany:labarge_inc
# generalizations
# concept:biotechcompany:fauquier_bankshares_inc
# generalizations
# concept:biotechcompany:mastercard_international
# concept:companyalsoknownas
# concept:biotechcompany:mastercard_international
# concept:synonymfor
# concept:biotechcompany:comtech_telecommunications_corp
# generalizations
# concept:biotechcompany:stemcells_inc
# generalizations
# concept:biotechcompany:olympic_steel_inc
# generalizations
# concept:biotechcompany:drug_company_merck
# generalizations
# concept:biotechcompany:ventas__vtr
# generalizations
# concept:biotechcompany:cavalier_homes_inc
# generalizations
# concept:biotechcompany:douglas_emmett
# generalizations
# concept:museum:coventry_transport_museum
# generalizations
# concept:biotechcompany:skyline_corp
# generalizations
# concept:biotechcompany:raven_inds_inc
# generalizations
# concept:biotechcompany:tya_pharmaceuticals
# generalizations
# concept:biotechcompany:amaru_inc
# generalizations
# concept:biotechcompany:ruddick_corp
# generalizations
# concept:company:lionbridge_technologies
# generalizations
# concept:biotechcompany:bosnalijek_pharmaceuticals
# generalizations
# concept:biotechcompany:barnwell_industries_inc
# generalizations
# concept:biotechcompany:frisch_s_restaurants_inc
# generalizations
# concept:biotechcompany:smc_recordings_inc
# generalizations
# concept:biotechcompany:archer_daniels_midland_co
# generalizations
# concept:biotechcompany:bsd_medical_corporation
# generalizations
# concept:biotechcompany:pennsylvania_commerce_bancorp_inc
# generalizations
# concept:biotechcompany:carrizo_oil___gas
# generalizations
# concept:biotechcompany:acura_pharmaceuticals
# generalizations
# concept:biotechcompany:mindpix_corp
# generalizations
# concept:biotechcompany:belden_inc_
# generalizations
# concept:biotechcompany:qlik_technologies_inc
# generalizations
# concept:biotechcompany:reed_financial
# generalizations
# concept:biotechcompany:sutron_corp
# generalizations
# concept:biotechcompany:capital_bancorp_inc
# generalizations
# concept:biotechcompany:hillenbrand_inc
# generalizations
# concept:biotechcompany:neogen_corporation
# generalizations
# concept:biotechcompany:big_5_sporting_goods_corp
# generalizations
# concept:biotechcompany:pressure_biosciences_inc
# generalizations
# concept:company:noranda_inc_
# generalizations
# concept:biotechcompany:con_way_inc_
# generalizations
# concept:biotechcompany:parexel_international
# generalizations
# concept:biotechcompany:scotsman_industries_inc
# generalizations
# concept:biotechcompany:encysive_pharmaceuticals_inc
# generalizations
# concept:biotechcompany:extra_space_storage_inc
# concept:haswikipediaurl
# concept:biotechcompany:extra_space_storage_inc
# generalizations
# concept:biotechcompany:advanced_health_corp
# generalizations
# concept:biotechcompany:cost_plus_inc
# generalizations
# concept:biotechcompany:cost_plus_inc
# generalizations
# concept:biotechcompany:bone_care_international
# generalizations
# concept:biotechcompany:sagemark_companies_ltd
# generalizations
# concept:biotechcompany:nokia_corp
# generalizations
# concept:biotechcompany:nokia_corp
# generalizations
# concept:building:medical_college_of_georgia
# generalizations
# concept:biotechcompany:nexstar_broadcasting_group_inc
# generalizations
# concept:biotechcompany:proshares_ultrashort_ftse_xinhua_china_25
# generalizations
# concept:biotechcompany:blacksands_petroleum_inc
# generalizations
# concept:biotechcompany:richardson_electronics_ltd
# generalizations
# concept:biotechcompany:cytokinetics
# generalizations
# concept:company:ongc_videsh_limited
# generalizations
# concept:biotechcompany:biocoral_inc
# generalizations
# concept:biotechcompany:corning_inc
# generalizations
# concept:biotechcompany:corning_inc
# generalizations
# concept:biotechcompany:cadence_financial_corp
# generalizations
# concept:biotechcompany:harlan_laboratories
# generalizations
# concept:biotechcompany:icn_pharmaceuticals
# concept:agentworkedondrug
# concept:biotechcompany:icn_pharmaceuticals
# generalizations
# concept:biotechcompany:zambon_group
# generalizations
# concept:organization:pfizer_pharmaceuticals_group
# generalizations
# concept:biotechcompany:qep_resources
# generalizations
# concept:company:ppd
# concept:organizationhasperson
# concept:company:ppd
# concept:organizationhastopmember
# concept:company:ppd
# concept:organizationleadbyperson
# concept:company:ppd
# concept:worker
# concept:biotechcompany:metallica_resources_inc
# generalizations
# concept:company:reed_international
# generalizations
# concept:biotechcompany:security_national_financial_corp
# generalizations
# concept:organization:glaxosmithkline_group
# generalizations
# concept:biotechcompany:orbit_international_corp
# generalizations
# concept:biotechcompany:bankatlantic_bancorp
# generalizations
# concept:biotechcompany:central_garden___pet_co
# generalizations
# concept:biotechcompany:xl_capital_ltd
# generalizations
# concept:retailstore:costco_wholesale_corp
# concept:companyalsoknownas
# concept:retailstore:costco_wholesale_corp
# concept:organizationhasagent
# concept:retailstore:costco_wholesale_corp
# concept:organizationhasperson
# concept:retailstore:costco_wholesale_corp
# concept:organizationleadbyperson
# concept:retailstore:costco_wholesale_corp
# concept:organizationterminatedperson
# concept:retailstore:costco_wholesale_corp
# concept:subpartof
# concept:retailstore:costco_wholesale_corp
# concept:worker
# concept:retailstore:costco_wholesale_corp
# generalizations
# concept:retailstore:costco_wholesale_corp
# generalizations
# concept:retailstore:costco_wholesale_corp
# generalizations
# concept:biotechcompany:metricsinc
# generalizations
# concept:biotechcompany:canmex_minerals_corp
# generalizations
# concept:company:hyland_software
# generalizations
# concept:biotechcompany:fluka
# generalizations
# concept:biotechcompany:commscope_inc
# generalizations
# concept:biotechcompany:wipro_ltd
# generalizations
# concept:retailstore:home_depot_inc_
# generalizations
# concept:biotechcompany:abbott_pharmaceuticals
# generalizations
# concept:biotechcompany:biomerieux
# concept:haswikipediaurl
# concept:biotechcompany:biomerieux
# generalizations
# concept:biotechcompany:beckman_coulter
# generalizations
# concept:biotechcompany:rait_financial_trust
# generalizations
# concept:biotechcompany:hypercom_corp
# generalizations
# concept:biotechcompany:lowes_companies_inc
# generalizations
# concept:biotechcompany:grupo_aeroportuario_del_centro_norte_sab_de_cv
# generalizations
# concept:biotechcompany:old_rep_intl_corp
# generalizations
# concept:biotechcompany:witter_dean_world_currency_fund_l_p
# generalizations
# concept:biotechcompany:aerogen
# generalizations
# concept:biotechcompany:biosense_webster
# generalizations
# concept:biotechcompany:villarrica_volcano
# generalizations
# concept:biotechcompany:villarrica_volcano
# generalizations
# concept:biotechcompany:hei_inc
# generalizations
# concept:biotechcompany:span_america_medical
# generalizations
# concept:biotechcompany:ingram_micro_inc
# generalizations
# concept:biotechcompany:clifton_savings
# generalizations
# concept:biotechcompany:cholestech
# generalizations
# concept:biotechcompany:caraco_pharmaceutical_laboratories
# generalizations
# concept:biotechcompany:utek_corp
# generalizations
# concept:biotechcompany:yrc_worldwide_inc
# generalizations
# concept:biotechcompany:marriott_intl
# generalizations
# concept:biotechcompany:genta_inc
# generalizations
# concept:biotechcompany:flow_international_corp
# generalizations
# concept:biotechcompany:autodesk_inc
# generalizations
# concept:biotechcompany:first_data_corp
# generalizations
# concept:biotechcompany:crocotta_energy_inc
# generalizations
# concept:biotechcompany:donegal_group_inc
# generalizations
# concept:biotechcompany:epiq_systems_inc
# generalizations
# concept:biotechcompany:telecomm_industries_corp
# generalizations
# concept:biotechcompany:ncr_corp
# generalizations
# concept:biotechcompany:cenes_pharmaceuticals
# generalizations
# concept:biotechcompany:proshares_ultrashort_semiconductors
# generalizations
# concept:biotechcompany:mednax_inc
# generalizations
# concept:biotechcompany:sunopta_inc
# concept:haswikipediaurl
# concept:biotechcompany:sunopta_inc
# generalizations
# concept:biotechcompany:syntax_brillian_corp
# generalizations
# concept:biotechcompany:vinco
# concept:haswikipediaurl
# concept:biotechcompany:zap
# generalizations
# concept:biotechcompany:lasalle_hotel_properties
# generalizations
# concept:biotechcompany:lasalle_hotel_properties
# generalizations
# concept:biotechcompany:crescent_banking_co
# generalizations
# concept:biotechcompany:aero_vodochody_l_39
# generalizations
# concept:biotechcompany:sound_pharmaceuticals
# generalizations
# concept:biotechcompany:slm_holding_corp
# generalizations
# concept:biotechcompany:global_industries
# generalizations
# concept:biotechcompany:hormel_foods_corp
# generalizations
# concept:biotechcompany:newbridge_bancorp
# generalizations
# concept:biotechcompany:tut_systems_inc
# generalizations
# concept:biotechcompany:conair_corp
# generalizations
# concept:biotechcompany:genitope
# generalizations
# concept:biotechcompany:southwest_gas_corporation
# generalizations
# concept:biotechcompany:maidenform_brands_inc
# generalizations
# concept:biotechcompany:cet_services_inc
# generalizations
# concept:biotechcompany:mdc_partners_inc
# generalizations
# concept:biotechcompany:sanofi_synthelabo_inc
# generalizations
# concept:biotechcompany:kramer_laboratories
# generalizations
# concept:biotechcompany:blue_chip_value_fund_inc
# generalizations
# concept:biotechcompany:somerset_pharmaceuticals_inc
# generalizations
# concept:biotechcompany:international_medical_group
# generalizations
# concept:biotechcompany:united_dominion_industries_limited
# generalizations
# concept:biotechcompany:cellzome
# generalizations
# concept:company:cheveron
# concept:latitudelongitude
# concept:company:cheveron
# generalizations
# concept:biotechcompany:panavision_inc
# generalizations
# concept:biotechcompany:taubman_centers_inc
# generalizations
# concept:biotechcompany:biotel_inc
# generalizations
# concept:biotechcompany:ascent_media_corp
# generalizations
# concept:biotechcompany:community_west_bancshares
# generalizations
# concept:biotechcompany:winmark_corp
# generalizations
# concept:biotechcompany:lubys_inc
# generalizations
# concept:biotechcompany:echelon_corporation
# concept:synonymfor
# concept:biotechcompany:echelon_corporation
# generalizations
# concept:biotechcompany:echelon_corporation
# generalizations
# concept:retailstore:subway
# concept:agentcompeteswithagent
# concept:retailstore:subway
# concept:transportationincity
# concept:retailstore:subway
# generalizations
# concept:biotechcompany:n1_2_areas_covered_in_this_report
# generalizations
# concept:biotechcompany:fairfax_financial_holdings_limited
# generalizations
# concept:biotechcompany:shire_biochem
# generalizations
# concept:biotechcompany:meridian_medical_technologies
# generalizations
# concept:shoppingmall:tysons_galleria
# generalizations
# concept:biotechcompany:pfizer_company
# generalizations
# concept:biotechcompany:sandy_spring_wtvr_tv_bancorp_inc
# generalizations
# concept:biotechcompany:orbital_sciences
# generalizations
# concept:biotechcompany:eplus_inc
# generalizations
# concept:biotechcompany:genetic_technologies_grants
# generalizations
# concept:biotechcompany:sense_technologies_inc
# generalizations
# concept:biotechcompany:transtech
# concept:haswikipediaurl
# concept:biotechcompany:transtech
# generalizations
# concept:biotechcompany:premiere_global_svcs_inc
# generalizations
# concept:biotechcompany:bristol_myers
# concept:agentworkedondrug
# concept:biotechcompany:bristol_myers
# generalizations
# concept:biotechcompany:ostex
# generalizations
# concept:mountain:taal_volcano
# generalizations
# concept:biotechcompany:novartis_international_ag
# generalizations
# concept:biotechcompany:home_properties_inc
# concept:haswikipediaurl
# concept:biotechcompany:home_properties_inc
# generalizations
# concept:biotechcompany:cell_signaling
# generalizations
# concept:biotechcompany:inovio_pharmaceuticals_inc
# generalizations
# concept:biotechcompany:helix_medical
# generalizations
# concept:biotechcompany:insmed_incorporated
# generalizations
# concept:biotechcompany:colony_rih_holdings_inc
# generalizations
# concept:biotechcompany:inrange_technologies_corp
# generalizations
# concept:biotechcompany:encore_medical
# generalizations
# concept:company:pepsico_foods
# generalizations
# concept:biotechcompany:nvr_inc
# generalizations
# concept:biotechcompany:cephalon___inc
# generalizations
# concept:biotechcompany:biomed_realty_trust_inc
# generalizations
# concept:retailstore:parkson
# generalizations
# concept:retailstore:parkson
# generalizations
# concept:biotechcompany:c_m_s_bancorp_inc
# generalizations
# concept:company:genencor
# generalizations
# concept:biotechcompany:select_comfort_corporation
# generalizations
# concept:biotechcompany:electroregenesis_inc
# generalizations
# concept:biotechcompany:pc_connection_inc
# generalizations
# concept:biotechcompany:pc_connection_inc
# generalizations
# concept:retailstore:fedex_corp
# concept:companyalsoknownas
# concept:retailstore:fedex_corp
# concept:organizationheadquarteredincountry
# concept:retailstore:fedex_corp
# generalizations
# concept:retailstore:fedex_corp
# generalizations

# %%
len(set(relation))
# Out:
# 61

# %%
concept = dataset['train']['value'][1 : 10001]

# %%
best_entity_ls = dataset['train']["best_entity_literal_string"][1 : 10001]

# %%
best_concept_ls = dataset['train']["best_value_literal_string"][1 : 10001]

# %%
df = pd.DataFrame( {"entity" : entity, "concept" : concept, "relation" : relation} )

# %%
df.to_csv("nell.csv", index = False)

# %%
df = pd.DataFrame( {"entity" : entity, "concept" : concept, "relation" : en_relation} )
df.to_csv("nell-new.csv", index = False)

# %%
df_node = pd.read_csv("nell-node.csv", sep = ",")

# %%
df_node
# Out:
#                                                  entity            relation  \
# 0         concept:biotechcompany:aspect_medical_systems     generalizations
# 1                        concept:company:limited_brands  concept:companyceo
# 2                        concept:company:limited_brands     generalizations
# 3                        concept:company:limited_brands     generalizations
# 4                 concept:biotechcompany:calavo_growers     generalizations
# ...                                                 ...                 ...
# 9643    concept:biotechcompany:the_immune_response_corp     generalizations
# 9644               concept:biotechcompany:tb_woods_corp     generalizations
# 9645            concept:biotechcompany:lan_airlines_s_a     generalizations
# 9646       concept:biotechcompany:orbital_sciences_corp     generalizations
# 9647  concept:biotechcompany:centerstate_banks_of_fl...     generalizations
#
#                      best-entity-query best-concept-query  \
# 0               Aspect Medical Systems                NaN
# 1                       limited brands      Leslie-Wexner
# 2                       limited brands                NaN
# 3                       limited brands                NaN
# 4                       Calavo Growers                NaN
# ...                                ...                ...
# 9643          the_immune_response_corp                NaN
# 9644                     tb woods corp                NaN
# 9645                  Lan Airlines S.A                NaN
# 9646             orbital sciences corp                NaN
# 9647  centerstate banks of florida inc                NaN
#
#                                   query
# 0               Aspect Medical Systems
# 1          limited brands Leslie-Wexner
# 2                       limited brands
# 3                       limited brands
# 4                       Calavo Growers
# ...                                 ...
# 9643          the_immune_response_corp
# 9644                     tb woods corp
# 9645                  Lan Airlines S.A
# 9646             orbital sciences corp
# 9647  centerstate banks of florida inc
#
# [9648 rows x 5 columns]

# %%
from absl import logging
import tensorflow as tf
import tensorflow_hub as hub

module_url = "./universal/"

tf.__version__
# Out:
# '1.15.0'

# %%
# Import the Universal Sentence Encoder's TF Hub module
embed = hub.Module(module_url)

# Compute a representation for each message, showing various lengths supported.
word = "Elephant"
sentence = "I am a sentence for which I would like to get its embedding."
paragraph = (
    "Universal Sentence Encoder embeddings also support short paragraphs. "
    "There is no hard limit on how long the paragraph is. Roughly, the longer "
    "the more 'diluted' the embedding will be.")
messages = [word, sentence, paragraph]

# Reduce logging output.
logging.set_verbosity(logging.ERROR)

with tf.Session() as session:
  session.run([tf.global_variables_initializer(), tf.tables_initializer()])
  message_embeddings = session.run(embed(messages))

  for i, message_embedding in enumerate(np.array(message_embeddings).tolist()):
    print("Message: {}".format(messages[i]))
    print("Embedding size: {}".format(len(message_embedding)))
    message_embedding_snippet = ", ".join(
        (str(x) for x in message_embedding[:3]))
    print("Embedding: [{}, ...]\n".format(message_embedding_snippet))
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# Message: Elephant
# Embedding size: 512
# Embedding: [0.04498472437262535, -0.05743393674492836, 0.002211477607488632, ...]
#
# Message: I am a sentence for which I would like to get its embedding.
# Embedding size: 512
# Embedding: [0.055680178105831146, -0.00960793811827898, 0.006246280390769243, ...]
#
# Message: Universal Sentence Encoder embeddings also support short paragraphs. There is no hard limit on how long the paragraph is. Roughly, the longer the more 'diluted' the embedding will be.
# Embedding size: 512
# Embedding: [0.03874939680099487, 0.0765201672911644, -0.0007945839897729456, ...]

# %%
query = df_node['query']

equery = []

with tf.Session() as session:
    session.run([tf.global_variables_initializer(), tf.tables_initializer()])
    
    query_embeddings = session.run(embed(query))

    for i, embedding in enumerate(np.array(query_embeddings).tolist()):
        equery.append(embedding)
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore

# %%
feature = pd.DataFrame( {"entity" : df_node['entity'], 'embedded-query' : equery} )
feature.to_csv("nell-node-feature.csv", sep = '\t', index = False)

# %%
new_feature = pd.read_csv("nell-node-feature.csv", sep = '\t')
new_feature.to_csv("nell-node-feature.gz", sep = '\t', index = False, compression = 'gzip')

# %%
data = pd.read_csv("nell-new.csv", sep = ',', header = None)
len(data[0].unique()), len(data[1].unique()), len(data[2].unique())
# Out:
# (6182, 1730, 60)
